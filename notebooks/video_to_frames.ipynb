# %%
# Importing all necessary libraries 
import cv2 
import os 

# Read the video from specified path 
cam = cv2.VideoCapture("./2022-06-16T17-07-10/Frames.m4v") 
image_dir = 'D:/Imperial/FYP/captured_data/campus_v2_test'
try: 
	
	# creating a folder named data 
	if not os.path.exists(image_dir): 
		os.makedirs(image_dir) 

# if not created then raise error 
except OSError: 
	print ('Error: Creating directory of data') 

# frame 
currentframe = 0

while(True): 

    # reading from frame 
    ret,frame = cam.read() 
    if ret: 
        # if video is still left continue creating images 
        name = image_dir +'/frame_' + str(currentframe) + '.jpg'
        resized = cv2.resize(frame, (640, 480), interpolation = cv2.INTER_AREA)
        # writing the extracted images 
        # if currentframe % 3 == 0:
        print ('Creating...' + name) 
        cv2.imwrite(name, resized) 

        # increasing counter so that it will 
        # show how many frames are created 
        currentframe += 1
    else: 
        break

# Release all space and windows once done 
cam.release() 
cv2.destroyAllWindows()
# Out:
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_0.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_1.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_2.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_3.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_4.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_5.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_6.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_7.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_8.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_9.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_10.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_11.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_12.jpg
# Creating...D:/Imperial/FYP/captured_data/campus_v2_test/frame_13.jpg
# ...
