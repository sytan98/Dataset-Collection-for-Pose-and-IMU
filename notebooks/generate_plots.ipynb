# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="whitegrid")

# %%
import matplotlib.image as mpimg
plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
img = mpimg.imread("D:\Imperial\FYP\\7Scenes\heads\seq-01\\frame-000175.color.png")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,2)
img = mpimg.imread("D:\Imperial\FYP\\7Scenes\heads\seq-01\\frame-000943.color.png")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,3)
img = mpimg.imread("D:\Imperial\FYP\\7Scenes\heads\seq-01\\frame-000334.color.png")
plt.imshow(img)
plt.axis('off')
plt.savefig("test.png", bbox_inches='tight')

# %%
#['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Noisy_v1', 0.6, "Absolute Translation (m)"],  ['Noisy_v1', 0.97, "Absolute Orientation (deg)"], 
        ['Noisy_v2', 1.75, "Absolute Translation (m)"], ['Noisy_v2', 3.50, "Absolute Orientation (deg)"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error", "Type"])

# %%
ax = sns.barplot(x="Dataset", y="Median Error", hue="Type", data=df).set(title = "Absolute Pose Deviation from Original Training Trajectory")
plt.show()

# %%
# ['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Original Training Poses', 0.0, "Using absolute poses"],  
        ['Original Training Poses', 0.28, "Using IMU"],  
        ['Noisy_v1', 0.82, "Using absolute poses"], 
        ['Noisy_v1', 0.49, "Using IMU"], 
        ['Noisy_v2', 1.33, "Using absolute poses"], 
        ['Noisy_v2', 1.09, "Using IMU"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error (m)", "Derivation Method"])

# %%
ax = sns.barplot(x="Dataset", y="Median Error (m)", hue="Derivation Method", data=df)\
                .set(title = "Relative Translation Errors")
plt.show()

# %%
# ['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Original Training Poses', 0.0, "Using absolute poses"],  
        ['Original Training Poses', 2.35, "Using IMU"],  
        ['Noisy_v1', 1.75, "Using absolute poses"], 
        ['Noisy_v1', 3.40, "Using IMU"], 
        ['Noisy_v2', 3.50, "Using absolute poses"], 
        ['Noisy_v2', 5.09, "Using IMU"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error (deg)", "Derivation Method"])

# %%
ax = sns.barplot(x="Dataset", y="Median Error (deg)", hue="Derivation Method", data=df)\
        .set(title = "Relative Orientation Errors")
plt.show()

# %%
#['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Original Training Poses', 1.18, "Absolute Translation (m)"], 
        ['Noisy_v1', 1.29, "Absolute Translation (m)"], 
        ['Noisy_v2', 1.43, "Absolute Translation (m)"]] 
df = pd.DataFrame(data, columns=["Dataset", "Median Error (m)", "Type"])

# %%
ax = sns.barplot(x="Dataset", y="Median Error (m)", data=df)\
        .set(title = "Baseline MapNet Absolute Translation Errors")
plt.show()

# %%
data = [['Original Training Poses', 8.25, "Absolute Orientation (deg)"], 
        ['Noisy_v1', 9.48, "Absolute Orientation (deg)"], 
        ['Noisy_v2', 11.55, "Absolute Orientation (deg)"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error (deg)", "Type"])

# %%
ax = sns.barplot(x="Dataset", y="Median Error (deg)", data=df)

# %%
data = [['0.0', 1.29, "Noisy_v1"], 
        ['0.0', 1.43, "Noisy_v2"], 
        ['0.25', 1.15, "Noisy_v1"], 
        ['0.25', 1.26, "Noisy_v2"],
        ['0.5', 1.28, "Noisy_v1"],
        ['0.5', 1.31, "Noisy_v2"],
        ['0.75', 1.14, "Noisy_v1"],
        ['0.75', 1.36, "Noisy_v2"],
        ['1.0', 1.20, "Noisy_v1"],
        ['1.0', 1.36, "Noisy_v2"]]
df = pd.DataFrame(data, columns=["alpha", "Median Error (m)", "Training Trajectory"])

# %%
sns.lineplot(data=df, x="alpha", y="Median Error (m)", hue="Training Trajectory")\
        .set(title = "Translation Error for varying imu weight")
plt.show()

# %%
data = [['0.0', 9.48, "Noisy_v1"], 
        ['0.0', 11.55, "Noisy_v2"], 
        ['0.25', 9.46, "Noisy_v1"], 
        ['0.25', 8.71, "Noisy_v2"],
        ['0.5', 9.10, "Noisy_v1"],
        ['0.5', 8.29, "Noisy_v2"],
        ['0.75', 7.57, "Noisy_v1"],
        ['0.75', 8.64, "Noisy_v2"],
        ['1.0', 9.42, "Noisy_v1"],
        ['1.0', 10.70, "Noisy_v2"]]
df = pd.DataFrame(data, columns=["alpha", "Median Error (deg)", "Training Trajectory"])

# %%
sns.lineplot(data=df, x="alpha", y="Median Error (deg)", hue="Training Trajectory")\
        .set(title = "Orientation Error for varying imu weight")
plt.show()
