# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
sns.set_theme(style="whitegrid")

# %% [markdown]
# ## 7 Scenes Heads

# %%
import matplotlib.image as mpimg
plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
img = mpimg.imread("D:\Imperial\FYP\\7Scenes\heads\seq-01\\frame-000175.color.png")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,2)
img = mpimg.imread("D:\Imperial\FYP\\7Scenes\heads\seq-01\\frame-000943.color.png")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,3)
img = mpimg.imread("D:\Imperial\FYP\\7Scenes\heads\seq-01\\frame-000334.color.png")
plt.imshow(img)
plt.axis('off')
plt.savefig("test.png", bbox_inches='tight')

# %% [markdown]
# ## AirSim Dataset Images

# %%
import matplotlib.image as mpimg
plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
img = mpimg.imread("D:\Imperial\FYP\captured_data\\airsim_drone_mode\\building_10fps\\train_new_2\images\\0.png")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,2)
img = mpimg.imread("D:\Imperial\FYP\captured_data\\airsim_drone_mode\\building_10fps\\train_new_2\images\\7000.png")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,3)
img = mpimg.imread("D:\Imperial\FYP\captured_data\\airsim_drone_mode\\building_10fps\\train_new_2\images\\12000.png")
plt.imshow(img)
plt.axis('off')
plt.savefig("airsim_dataset.png", bbox_inches='tight')

# %% [markdown]
# ## Real World Dataset Images

# %%
import matplotlib.image as mpimg
plt.figure(figsize=(15,10))
plt.subplot(1,3,1)
img = mpimg.imread("D:\Imperial\FYP\captured_data\campus_v3\\train\\images\\frame_400.jpg")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,2)
img = mpimg.imread("D:\Imperial\FYP\captured_data\campus_v3\\train\\images\\frame_700.jpg")
plt.imshow(img)
plt.axis('off')
plt.subplot(1,3,3)
img = mpimg.imread("D:\Imperial\FYP\captured_data\campus_v3\\train\\images\\frame_1200.jpg")
plt.imshow(img)
plt.axis('off')
plt.savefig("campus_dataset.png", bbox_inches='tight')

# %% [markdown]
# ## AirSim Dataset stats

# %%
#['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Noisy_v1', 0.6, "Absolute Translation (m)"],  ['Noisy_v1', 5.30, "Absolute Orientation (deg)"], 
        ['Noisy_v2', 0.96, "Absolute Translation (m)"], ['Noisy_v2', 8.81, "Absolute Orientation (deg)"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error", "Type"])
ax = sns.barplot(x="Dataset", y="Median Error", hue="Type", data=df)
ax.set(title = "Absolute Pose Deviation from Original Training Trajectory")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
# ['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Original Training Poses', 0.0, "Using absolute poses"],  
        ['Original Training Poses', 0.19, "Using IMU"],  
        ['Noisy_v1', 0.83, "Using absolute poses"], 
        ['Noisy_v1', 0.22, "Using IMU"], 
        ['Noisy_v2', 1.34, "Using absolute poses"], 
        ['Noisy_v2', 0.26, "Using IMU"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error (m)", "Derivation Method"])

# %%
ax = sns.barplot(x="Dataset", y="Median Error (m)", hue="Derivation Method", data=df)
ax.set(title = "Relative Translation Errors")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
# ['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Original Training Poses', 0.0, "Using absolute poses"],  
        ['Original Training Poses', 3.13, "Using IMU"],  
        ['Noisy_v1', 6.97, "Using absolute poses"], 
        ['Noisy_v1', 3.13, "Using IMU"], 
        ['Noisy_v2', 11.60, "Using absolute poses"], 
        ['Noisy_v2', 3.13, "Using IMU"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error (deg)", "Derivation Method"])

# %%
ax = sns.barplot(x="Dataset", y="Median Error (deg)", hue="Derivation Method", data=df)
ax.set(title = "Relative Orientation Errors")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %% [markdown]
# ## Experiments

# %%
#['original', 0, "Absolute Translation (m)"], ['original', 0, "Absolute Orientation (deg)"], 
data = [['Original Training Poses', 1.46, "Absolute Translation (m)"], 
        ['Noisy_v1', 1.52, "Absolute Translation (m)"], 
        ['Noisy_v2', 1.58, "Absolute Translation (m)"]] 
df = pd.DataFrame(data, columns=["Dataset", "Median Error (m)", "Type"])
ax = sns.barplot(x="Dataset", y="Median Error (m)", data=df)
ax.set(title = "Baseline MapNet Absolute Translation Errors")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
data = [['Original Training Poses', 10.78, "Absolute Orientation (deg)"], 
        ['Noisy_v1', 11.34, "Absolute Orientation (deg)"], 
        ['Noisy_v2', 15.72
        , "Absolute Orientation (deg)"]]
df = pd.DataFrame(data, columns=["Dataset", "Median Error (deg)", "Type"])
ax = sns.barplot(x="Dataset", y="Median Error (deg)", data=df)
ax.set(title = "Baseline MapNet Absolute Orientation Errors")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
data = [['0.0', 1.46, "Original"], 
        ['0.0', 1.52, "Noisy_v1"], 
        ['0.0', 1.58, "Noisy_v2"], 
        ['0.25', 1.28, "Original"], 
        ['0.25', 1.41, "Noisy_v1"], 
        ['0.25', 1.49, "Noisy_v2"],
        ['0.5', 1.41, "Original"], 
        ['0.5', 1.44, "Noisy_v1"],
        ['0.5', 1.59, "Noisy_v2"],
        # ['0.75', 1.14, "Noisy_v1"],
        # ['0.75', 1.36, "Noisy_v2"],
        ['1.0', 1.35, "Original"], 
        ['1.0', 1.65, "Noisy_v1"],
        ['1.0', 1.45, "Noisy_v2"]]
# data = [['0.0', 1.92, "Original"], 
#         ['0.0', 1.84, "Noisy_v1"], 
#         ['0.0', 1.92, "Noisy_v2"], 
#         # ['0.25', 1.15, "Noisy_v1"], 
#         # ['0.25', 1.26, "Noisy_v2"],
#         ['0.5', 1.67, "Original"], 
#         ['0.5', 1.81, "Noisy_v1"],
#         ['0.5', 1.99, "Noisy_v2"],
#         # ['0.75', 1.14, "Noisy_v1"],
#         # ['0.75', 1.36, "Noisy_v2"],
#         ['1.0', 1.58, "Original"], 
#         ['1.0', 1.86, "Noisy_v1"],
#         ['1.0', 1.61, "Noisy_v2"]]
df = pd.DataFrame(data, columns=["alpha", "Median Error (m)", "Training Trajectory"])

sns.lineplot(data=df, x="alpha", y="Median Error (m)", hue="Training Trajectory", marker="o")\
        .set(title = "Translation Error for varying imu weight")
plt.show()

# %%
data = [['0.0', 10.81, "Original"], 
        ['0.0', 11.32, "Noisy_v1"], 
        ['0.0', 15.71, "Noisy_v2"], 
        ['0.25', 8.99, "Original"], 
        ['0.25', 12.32, "Noisy_v1"], 
        ['0.25', 11.01, "Noisy_v2"],
        ['0.5', 9.56, "Original"], 
        ['0.5', 10.34, "Noisy_v1"],
        ['0.5', 12.25, "Noisy_v2"],
        # ['0.75', 7.57, "Noisy_v1"],
        # ['0.75', 8.64, "Noisy_v2"],
        ['1.0', 8.69, "Original"], 
        ['1.0', 13.18, "Noisy_v1"],
        ['1.0', 12.90, "Noisy_v2"]]
df = pd.DataFrame(data, columns=["alpha", "Median Error (deg)", "Training Trajectory"])
ax = sns.lineplot(data=df, x="alpha", y="Median Error (deg)", hue="Training Trajectory", marker="o")
ax.set(title = "Orientation Error for varying imu weight")
plt.show()

# %%
data = [['Baseline', 1.46, "Original"], 
        ['Baseline', 1.52, "Noisy_v1"], 
        ['Baseline', 1.58, "Noisy_v2"], 
        ['Average Output Model', 1.32, "Original"], 
        ['Average Output Model', 1.53, "Noisy_v1"],
        ['Average Output Model', 1.69, "Noisy_v2"],]

df = pd.DataFrame(data, columns=["alpha", "Median Error (m)", "Training Trajectory"])
ax = sns.barplot(data=df, x="alpha", y="Median Error (m)", hue="Training Trajectory")
ax.set(title = "Translation Error when Average Output Method is used")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
data = [['Baseline', 10.78, "Original"], 
        ['Baseline', 11.34, "Noisy_v1"], 
        ['Baseline', 15.72, "Noisy_v2"], 
        ['Average Output Model', 11.46, "Original"], 
        ['Average Output Model', 12.07, "Noisy_v1"],
        ['Average Output Model', 13.18, "Noisy_v2"],]

df = pd.DataFrame(data, columns=["Model", "Median Error (deg)", "Training Trajectory"])
ax = sns.barplot(data=df, x="Model", y="Median Error (deg)", hue="Training Trajectory")
ax.set(title = "Orientation Error when Average Output Method is used")
for container in ax.containers:
    ax.bar_label(container)
plt.legend(title="Training Trajectory", loc="lower center")
plt.show()

# %%
data = [['Simple', 18.78, "Original"], 
        ['Simple', 20.62, "Noisy_v1"], 
        ['Simple', 22.22, "Noisy_v2"], 
        ['Interpolate', 16.32, "Original"], 
        ['Interpolate', 19.35, "Noisy_v1"],
        ['Interpolate', 19.34, "Noisy_v2"],]

df = pd.DataFrame(data, columns=["Averaging Method", "Mean Error (deg)", "Training Trajectory"])
ax = sns.barplot(data=df, hue="Averaging Method", y="Mean Error (deg)", x="Training Trajectory")
ax.set(title = "Comparison between simple average and interpolation method")
for container in ax.containers:
    ax.bar_label(container)
plt.legend(title="Averaging Method",loc="lower left")
plt.show()

# %%
data = [['5', 1.41, "Original"], 
        ['5', 1.44, "Noisy_v1"],
        ['5', 1.59, "Noisy_v2"],
        ['10', 1.52, "Original"], 
        ['10', 1.41, "Noisy_v1"],
        ['10', 1.66, "Noisy_v2"]]
df = pd.DataFrame(data, columns=["k", "Median Error (m)", "Training Trajectory"])

ax = sns.barplot(data=df, x="Training Trajectory", y="Median Error (m)", hue="k")
ax.set(title = "Translation Error for varying imu weight")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
data = [['5', 9.56, "Original"], 
        ['5', 10.34, "Noisy_v1"],
        ['5', 12.25, "Noisy_v2"],
        ['10', 8.71, "Original"], 
        ['10', 9.99, "Noisy_v1"],
        ['10', 16.45, "Noisy_v2"]]
df = pd.DataFrame(data, columns=["k", "Median Error (deg)", "Training Trajectory"])

ax = sns.barplot(data=df, x="Training Trajectory", y="Median Error (deg)", hue="k")
ax.set(title = "Orientation Error for varying imu weight")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %% [markdown]
# ## Real world dataset experiments

# %%
data = [['COLMAP Ground Truth', 0.38, "Baseline Method"],  
        ['COLMAP Ground Truth', 0.41, "IMU average alpha = 0.5"], 
        ['Noise added', 0.41, "Baseline Method"], 
        ['Noise added', 0.40, "IMU average alpha = 0.5"]]
df = pd.DataFrame(data, columns=["Training Trajectory", "Median Error (m)", "Model"])
ax = sns.barplot(x="Training Trajectory", y="Median Error (m)", hue="Model", data=df)
ax.set(title = "Absolute translation error on real-world dataset")
plt.legend(loc="lower left")
for container in ax.containers:
    ax.bar_label(container)
plt.show()

# %%
data = [['COLMAP Ground Truth', 12.13, "Baseline Method"],  
        ['COLMAP Ground Truth', 11.66, "IMU average alpha = 0.5"], 
        ['Noise added', 15.57, "Baseline Method"], 
        ['Noise added', 14.35, "IMU average alpha = 0.5"]]
df = pd.DataFrame(data, columns=["Training Trajectory", "Median Error (deg)", "Model"])
ax = sns.barplot(x="Training Trajectory", y="Median Error (deg)", hue="Model", data=df)
ax.set(title = "Absolute orientation error on real-world dataset")
plt.legend(loc="lower left")
for container in ax.containers:
    ax.bar_label(container)
plt.show()
